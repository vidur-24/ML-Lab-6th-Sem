# %% [markdown]
# ---
#
# <h1 align="center">Assignment-4 [Vidur Dua (23124119)]</h1>
#
# ---

# %% [markdown]
# ## Q1
# Write a Python program to compute linear regression parameters using the closed form solution.

# %%
import numpy as np

X = np.array([[1], [2], [3], [4], [5]])
y = np.array([2, 4, 5, 4, 5])

X_b = np.c_[np.ones((X.shape[0], 1)), X]

theta = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)

intercept = theta[0]
slope = theta[1]

print("Intercept (theta_0):", intercept)
print("Slope (theta_1):", slope)
# Out:
# Intercept (theta_0): 2.2000000000000046
# Slope (theta_1): 0.6000000000000002
